# %%
import astropy as ast
from astropy.coordinates import solar_system_ephemeris, EarthLocation, GeocentricTrueEcliptic, get_body, SkyCoord, Distance
from astroplan.moon import moon_phase_angle
from collections import defaultdict
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook

# %% [markdown]
# ### Generating Data From Celestial Bodies

# %%
# All of the celestial bodies to generate synthetic data on
BODY_NAMES = ['mercury', 'venus', 'mars', 'jupiter', 'saturn', 'moon', 'sun']

# %%
def get_coordinates(body):
    # Takes a Skycoord object, returns (theta, phi, r, x, y, z) in (deg, deg, AU, AU, AU, AU)
    angles = [float(i) for i in body.to_string().split(' ')]
    body_dist_string = body.distance.to_string()
    r = float(body_dist_string[:-3])
    units = body_dist_string[-2:]
    if units == 'km':
        r /= 1.496e+8
    
    phi = angles[0]
    theta = angles[1]

    # Extract the Cartesian coordinates from the SkyCoord object
    c = body.cartesian
    x = c.x.value
    y = c.y.value
    z = c.z.value

    body_dist_string = body.distance.to_string()
    units = body_dist_string[-2:]
    
    # Convert from km to AU if necessary
    if units == 'km':
        x /= 1.496e+8
        y /= 1.496e+8
        z /= 1.496e+8
    return (phi, theta, r, x, y, z)

# %%
def add_noise(coords):
    # Takes a tuple of (theta, phi, r, x, y, z) in (deg, deg, AU, AU, AU, AU)
    # and returns a noisified version of the data
    # Currently doesn't add noise to r
    theta, phi, r, x, y, z = coords
    return (theta + np.random.normal(0,1), phi + np.random.normal(0,1), r + np.random.normal(0, 0.1),
            x + np.random.normal(0, 0.1), y + np.random.normal(0, 0.1), z + np.random.normal(0, 0.1))

# Range is 150 years, almost the limit available to us from the astropy API
times = pd.date_range(start="1850-01-01-00-00-00", end="2000-01-01-00-00-00", freq='5D')

# Location is the Medicina Radio Observatory, located in Italy. Chosen for proximity to Greece
loc = EarthLocation.of_site('medicina')
rows = defaultdict(list)

# %%
# Generate coordinate data in terms of spherical Geocentric Celestial Reference System (GCRS), default for astropy
for time in tqdm_notebook(times):
    time = ast.time.Time(time.to_pydatetime())
    bodies = []
    
    with solar_system_ephemeris.set('builtin'):
        for body_name in BODY_NAMES:
            bodies.append(get_body(body_name, time, loc))

    rows['time'].append(time)
    rows['location'].append(str(loc))
    rows['moon_phase'].append(moon_phase_angle(time).value)

    for body_name, body in zip(BODY_NAMES, bodies):
        coordinates = add_noise(get_coordinates(body))
        coord_strings = ['theta', 'phi', 'r', 'x', 'y', 'z']
        for i in range(len(coord_strings)):
            c = coordinates[i]
            rows[body_name + '_' + coord_strings[i]].append(c)

celestial_bodies = pd.DataFrame(rows)
celestial_bodies.to_csv('data.csv', index=False)
# Out:
# /Users/kaahan/miniconda3/envs/project_s/lib/python3.6/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10958.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2ceefe56278e> in <module>
#       6     with solar_system_ephemeris.set('builtin'):
#       7         for body_name in BODY_NAMES:
# ----> 8             bodies.append(get_body(body_name, time, loc))
#       9
#      10     rows['time'].append(time)
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/solar_system.py in get_body(body, time, location, ephemeris)
#     464
#     465     if location is not None:
# --> 466         obsgeoloc, obsgeovel = location.get_gcrs_posvel(time)
#     467     else:
#     468         obsgeoloc, obsgeovel = None, None
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/earth.py in get_gcrs_posvel(self, obstime)
#     694         """
#     695         # GCRS position
# --> 696         gcrs_data = self.get_gcrs(obstime).data
#     697         obsgeopos = gcrs_data.without_differentials()
#     698         obsgeovel = gcrs_data.differentials['s'].to_cartesian()
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/earth.py in get_gcrs(self, obstime)
#     674         zeros = np.broadcast_to(0. * u.km / u.s, (3,) + itrs.shape, subok=True)
#     675         itrs.data.differentials['s'] = CartesianDifferential(zeros)
# --> 676         return itrs.transform_to(GCRS(obstime=obstime))
#     677
#     678     def get_gcrs_posvel(self, obstime):
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/baseframe.py in transform_to(self, new_frame)
#    1218             msg = 'Cannot transform from {0} to {1}'
#    1219             raise ConvertError(msg.format(self.__class__, new_frame.__class__))
# -> 1220         return trans(self, new_frame)
#    1221
#    1222     def is_transformable_to(self, new_frame):
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1390
#    1391             curr_toframe = t.tosys(**frattrs)
# -> 1392             curr_coord = t(curr_coord, curr_toframe)
#    1393
#    1394         # this is safe even in the case where self.transforms is empty, because
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#     972                     else:
#     973                         back_frame = toframe
# --> 974                     back = supcall(from_diffless_back, back_frame)
#     975                 else:
#     976                     if self._diff_attr_in_fromsys:
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/builtin_frames/intermediate_rotation_transforms.py in cirs_to_gcrs(cirs_coo, gcrs_frame)
#      68
#      69     # now do any needed offsets (no-op if same obstime and 0 pos/vel)
# ---> 70     return gcrs.transform_to(gcrs_frame)
#      71
#      72
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/baseframe.py in transform_to(self, new_frame)
#    1218             msg = 'Cannot transform from {0} to {1}'
#    1219             raise ConvertError(msg.format(self.__class__, new_frame.__class__))
# -> 1220         return trans(self, new_frame)
#    1221
#    1222     def is_transformable_to(self, new_frame):
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1390
#    1391             curr_toframe = t.tosys(**frattrs)
# -> 1392             curr_coord = t(curr_coord, curr_toframe)
#    1393
#    1394         # this is safe even in the case where self.transforms is empty, because
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#     993             return reprwithoutdiff.realize_frame(reprwithdiff)
#     994         else:
# --> 995             return supcall(fromcoord, toframe)
#     996
#     997
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/builtin_frames/icrs_cirs_transforms.py in gcrs_to_gcrs(from_coo, to_frame)
#     219     else:
#     220         # like CIRS, we do this self-transform via ICRS
# --> 221         return from_coo.transform_to(ICRS).transform_to(to_frame)
#     222
#     223
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/baseframe.py in transform_to(self, new_frame)
#    1218             msg = 'Cannot transform from {0} to {1}'
#    1219             raise ConvertError(msg.format(self.__class__, new_frame.__class__))
# -> 1220         return trans(self, new_frame)
#    1221
#    1222     def is_transformable_to(self, new_frame):
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1390
#    1391             curr_toframe = t.tosys(**frattrs)
# -> 1392             curr_coord = t(curr_coord, curr_toframe)
#    1393
#    1394         # this is safe even in the case where self.transforms is empty, because
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#     993             return reprwithoutdiff.realize_frame(reprwithdiff)
#     994         else:
# --> 995             return supcall(fromcoord, toframe)
#     996
#     997
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/builtin_frames/icrs_cirs_transforms.py in gcrs_to_icrs(gcrs_coo, icrs_frame)
#     178     # coordinate direction
#     179     obs_pv = erfa.pav2pv(
# --> 180         gcrs_coo.obsgeoloc.get_xyz(xyz_axis=-1).to_value(u.m),
#     181         gcrs_coo.obsgeovel.get_xyz(xyz_axis=-1).to_value(u.m/u.s))
#     182
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/representation.py in get_xyz(self, xyz_axis)
#    1079                 return self._xyz
#    1080             else:
# -> 1081                 return np.moveaxis(self._xyz, self._xyz_axis, xyz_axis)
#    1082
#    1083         # Create combined array.  TO DO: keep it in _xyz for repeated use?
#
# <__array_function__ internals> in moveaxis(*args, **kwargs)
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/units/quantity.py in __array_function__(self, function, types, args, kwargs)
#    1491         # implementation.
#    1492         if function in SUBCLASS_SAFE_FUNCTIONS:
# -> 1493             return super().__array_function__(function, types, args, kwargs)
#    1494
#    1495         elif function in FUNCTION_HELPERS:
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/numpy/core/numeric.py in moveaxis(a, source, destination)
#    1432                          'the same number of elements')
#    1433
# -> 1434     order = [n for n in range(a.ndim) if n not in source]
#    1435
#    1436     for dest, src in sorted(zip(destination, source)):
#
# KeyboardInterrupt:

# %%
# Load the generated data (which needs to be converted to the geocentric ecliptic coordinate system)
data = pd.read_csv('data.csv')

# %%
# Convert coordinates to the standard geocentric true ecliptic coordinate system
# See https://docs.astropy.org/en/stable/api/astropy.coordinates.GeocentricTrueEcliptic.html for more documentation

rows = defaultdict(list)
for name in BODY_NAMES:
    phi_col = data[name + '_phi']
    theta_col = data[name + '_theta']
    r_col = data[name + '_r']
    for phi, theta, r in tqdm_notebook(zip(phi_col, theta_col, r_col)):
        ecliptic = SkyCoord(theta, phi, abs(r), frame='gcrs', unit=('deg', 'deg', 'AU')).transform_to(GeocentricTrueEcliptic())
        print(phi, theta, r)
        print(abs(r))
        print(ecliptic)
        coordinates = get_coordinates(ecliptic)
        coord_strings = ['lambda', 'beta', 'delta', 'x', 'y', 'z']
        for i in range(len(coord_strings)):
            c = coordinates[i]
            rows[name + '_' + coord_strings[i]].append(c)
# Out:
# /Users/kaahan/miniconda3/envs/project_s/lib/python3.6/site-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if __name__ == '__main__':
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# <SkyCoord (GeocentricTrueEcliptic: equinox=J2000.000, obstime=J2000.000): (lon, lat, distance) in (deg, deg, AU)
#     (279.15607302, -0.9459989, 1.13211587)>
# -24.542968 286.25935039999996 1.135955661
# 1.135955661
# <SkyCoord (GeocentricTrueEcliptic: equinox=J2000.000, obstime=J2000.000): (lon, lat, distance) in (deg, deg, AU)
#     (284.75988217, -1.93317139, 1.13595566)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f12cc126053d> in <module>
#       8     r_col = data[name + '_r']
#       9     for phi, theta, r in tqdm_notebook(zip(phi_col, theta_col, r_col)):
# ---> 10         ecliptic = SkyCoord(theta, phi, abs(r), frame='gcrs', unit=('deg', 'deg', 'AU')).transform_to(GeocentricTrueEcliptic())
#      11         print(phi, theta, r)
#      12         print(abs(r))
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/sky_coordinate.py in transform_to(self, frame, merge_attributes)
#     443         # Do the transformation, returning a coordinate frame of the desired
#     444         # final type (not generic).
# --> 445         new_coord = trans(self.frame, generic_frame)
#     446
#     447         # Finally make the new SkyCoord object from the `new_coord` and
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1390
#    1391             curr_toframe = t.tosys(**frattrs)
# -> 1392             curr_coord = t(curr_coord, curr_toframe)
#    1393
#    1394         # this is safe even in the case where self.transforms is empty, because
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#     993             return reprwithoutdiff.realize_frame(reprwithdiff)
#     994         else:
# --> 995             return supcall(fromcoord, toframe)
#     996
#     997
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/builtin_frames/ecliptic_transforms.py in gcrs_to_true_geoecliptic(gcrs_coo, to_frame)
#     147     gcrs_coo2 = gcrs_coo.transform_to(GCRS(obstime=to_frame.obstime))
#     148
# --> 149     rmat = _true_ecliptic_rotation_matrix(to_frame.equinox)
#     150     newrepr = gcrs_coo2.cartesian.transform(rmat)
#     151     return to_frame.realize_frame(newrepr)
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/coordinates/builtin_frames/ecliptic_transforms.py in _true_ecliptic_rotation_matrix(equinox)
#      43     # (see https://github.com/astropy/astropy/pull/6508).
#      44     jd1, jd2 = get_jd12(equinox, 'tt')
# ---> 45     rnpb = erfa.pnm06a(jd1, jd2)
#      46     _, nut_obl = erfa.nut06a(jd1, jd2)*u.radian
#      47     obl = erfa.obl06(jd1, jd2)*u.radian + nut_obl  # calculate the true obliquity of the ecliptic
#
# ~/miniconda3/envs/project_s/lib/python3.6/site-packages/astropy/_erfa/core.py in pnm06a(date1, date2)
#   10313
#   10314     """
# > 10315     rnpb = ufunc.pnm06a(date1, date2)
#   10316     return rnpb
#   10317
#
# KeyboardInterrupt:

# %%
# Prepare the final dataset as final_data.csv

final_data = pd.DataFrame(rows)
final_data['time'] = data['time'] # Time is given in yyyy-mm-dd hh:mm:ss format
final_data['location'] = data['location'] # Location is given as (longitude, latitude, height) in m
final_data['moon_phase'] = data['moon_phase'] # Moon phase 
final_data.to_csv('final_data.csv', index=False) # All other columns are the spherical and Cartesian geocentric true ecliptic coordinate system values as described in the writeup

# %%
final_data
